# %% [markdown]
# preprocessing

# %%
#cleaning
import pandas as pd
import numpy as np

data = pd.read_csv("AirQuality.csv", sep = ";")
data = data.drop(columns=["Unnamed: 15", "Unnamed: 16"])
data = data.replace(',', '.', regex=True)
data.replace(-200, np.nan, inplace=True)
df_filled = data.ffill().bfill()

for col in data.columns:
    if col not in ["Date", "Time"]:
        data[col] = pd.to_numeric(data[col], errors='coerce')

data['Time'] = data['Time'].str.replace('.', ':')
data['Datetime'] = pd.to_datetime(data['Date'] + ' ' + data['Time'], dayfirst=True)
data = data.drop(columns=['Date', 'Time'])
data = data.set_index('Datetime')

# Save cleaned dataset for downstream OC-SVM pipeline
data.to_csv("AirQuality_preprocessed.csv", index=True, index_label="Datetime")

data.head()
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# Datetime
# 2004-03-10 18:00:00     2.6       1360.0     150.0      11.9         1046.0
# 2004-03-10 19:00:00     2.0       1292.0     112.0       9.4          955.0
# 2004-03-10 20:00:00     2.2       1402.0      88.0       9.0          939.0
# 2004-03-10 21:00:00     2.2       1376.0      80.0       9.2          948.0
# 2004-03-10 22:00:00     1.6       1272.0      51.0       6.5          836.0
#
#                      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# Datetime
# 2004-03-10 18:00:00    166.0        1056.0    113.0        1692.0
# 2004-03-10 19:00:00    103.0        1174.0     92.0        1559.0
# 2004-03-10 20:00:00    131.0        1140.0    114.0        1555.0
# 2004-03-10 21:00:00    172.0        1092.0    122.0        1584.0
# 2004-03-10 22:00:00    131.0        1205.0    116.0        1490.0
#
#                      PT08.S5(O3)     T    RH      AH
# Datetime
# ...

# %%
# eda
data.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  8991.000000   914.000000  9357.000000    8991.000000
# mean    -34.207524  1099.833166   218.811816     1.865683     939.153376
# std      77.657170   217.080037   204.459921    41.380206     266.831429
# min    -200.000000   647.000000     7.000000  -200.000000     383.000000
# 25%       0.600000   937.000000    67.000000     4.000000     734.500000
# 50%       1.500000  1063.000000   150.000000     7.900000     909.000000
# 75%       2.600000  1231.000000   297.000000    13.600000    1116.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  7718.000000   8991.000000  7715.000000   8991.000000  8991.000000
# mean    246.896735    835.493605   113.091251   1456.264598  1022.906128
# std     212.979168    256.817320    48.370108    346.206794   398.484288
# ...

# %%
data.isna().sum()
# Out:
# CO(GT)            114
# PT08.S1(CO)       480
# NMHC(GT)         8557
# C6H6(GT)          114
# PT08.S2(NMHC)     480
# NOx(GT)          1753
# PT08.S3(NOx)      480
# NO2(GT)          1756
# PT08.S4(NO2)      480
# PT08.S5(O3)       480
# T                 114
# RH                114
# AH                114
# dtype: int64

# %%
import matplotlib.pyplot as plt

for col in data.columns:
    plt.figure(figsize=(12,4))
    data[col].plot()
    plt.title(col)
    plt.show()

# %%
important = ['CO(GT)', 'NO2(GT)', 'PT08.S1(CO)']

data[important].plot(subplots=True, figsize=(12,8))
plt.tight_layout()
plt.show()
